# %%
import pandas as pd
from scipy import stats
from pydataset import data
import numpy as np
import env
import os
import prepare
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %% [markdown]
# In a jupyter notebook, classification_exercises.ipynb, use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.
#
# print the first 3 rows

# %%
df_iris = data('iris')

# %% [markdown]
# print the number of rows and columns (shape)

# %%
df_iris.shape
# Out:
# (150, 5)

# %% [markdown]
# print the column names

# %%
list(df_iris.columns)
# Out:
# ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species']

# %% [markdown]
# print the data type of each column

# %%
df_iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %% [markdown]
# print the summary statistics for each of the numeric variables

# %%
df_iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Read the data from this google sheet into a dataframe, df_google.

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_google = pd.read_csv(csv_export_url)
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# print the first 3 rows

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# print the number of rows and columns

# %%
df_google.shape
# Out:
# (891, 12)

# %% [markdown]
# print the column names

# %%
list(df_google.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# print the data type of each column

# %%
df_google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# print the summary statistics for each of the numeric variables

# %%
df_google.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# print the unique values for each of your categorical variables

# %%
print(df_google.nunique())
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# Download the previous exercise's file into an excel (File → Download → Microsoft Excel). Read the downloaded file into a dataframe named df_excel.
#
# assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel = pd.read_excel('train.xlsx')
df_excel_sample = df_excel.head(100)

# %% [markdown]
# print the number of rows of your original dataframe

# %%
df_excel.shape[0]
# Out:
# 891

# %% [markdown]
# print the first 5 column names

# %%
df_excel.columns[0:5]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'], dtype='object')

# %% [markdown]
# print the column names that have a data type of object

# %%
df_excel.select_dtypes("object").columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# compute the range for each of the numeric variables.

# %%
titanic_stats = df_excel[['Age', 'Fare']].describe()
titanic_stats
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %% [markdown]
# Make a new python module, acquire.py to hold the following data aquisition functions:
#
# Make a function named get_titanic_data that returns the titanic data from the codeup data science database as a pandas data frame. Obtain your data from the Codeup Data Science Database.
#
# Make a function named get_iris_data that returns the data from the iris_db on the codeup data science database as a pandas data frame. The returned data frame should include the actual name of the species in addition to the species_ids. Obtain your data from the Codeup Data Science Database.
#
# Make a function named get_telco_data that returns the data from the telco_churn database in SQL. In your SQL, be sure to join contract_types, internet_service_types, payment_types tables with the customers table, so that the resulting dataframe contains all the contract, payment, and internet service options. Obtain your data from the Codeup Data Science Database.
#
# Once you've got your get_titanic_data, get_iris_data, and get_telco_data functions written, now it's time to add caching to them. To do this, edit the beginning of the function to check for the local filename of telco.csv, titanic.csv, or iris.csv. If they exist, use the .csv file. If the file doesn't exist, then produce the SQL and pandas necessary to create a dataframe, then write the dataframe to a .csv file with the appropriate name.

# %%
import acquire

# %% [markdown]
# Using the Iris Data:
#
# Use the function defined in acquire.py to load the iris data.

# %%
iris_df = acquire.get_iris_data()
iris_df.head()
# Out:
#    Unnamed: 0  species_id  measurement_id  sepal_length  sepal_width  \
# 0           0           1               1           5.1          3.5
# 1           1           1               2           4.9          3.0
# 2           2           1               3           4.7          3.2
# 3           3           1               4           4.6          3.1
# 4           4           1               5           5.0          3.6
#
#    petal_length  petal_width species_name
# 0           1.4          0.2       setosa
# 1           1.4          0.2       setosa
# 2           1.3          0.2       setosa
# 3           1.5          0.2       setosa
# 4           1.4          0.2       setosa

# %% [markdown]
# Drop the species_id and measurement_id columns.

# %%
iris_df.drop(['measurement_id','species_id'], axis = 1, inplace = True)

# %%
iris_df
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# 5             5           5.4          3.9           1.7          0.4
# 6             6           4.6          3.4           1.4          0.3
# 7             7           5.0          3.4           1.5          0.2
# 8             8           4.4          2.9           1.4          0.2
# 9             9           4.9          3.1           1.5          0.1
# 10           10           5.4          3.7           1.5          0.2
# 11           11           4.8          3.4           1.6          0.2
# ...

# %% [markdown]
# Rename the species_name column to just species.

# %%
iris_df.rename(columns = {'species_name':'species'}, inplace = True)

# %%
iris_df
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# 5             5           5.4          3.9           1.7          0.4
# 6             6           4.6          3.4           1.4          0.3
# 7             7           5.0          3.4           1.5          0.2
# 8             8           4.4          2.9           1.4          0.2
# 9             9           4.9          3.1           1.5          0.1
# 10           10           5.4          3.7           1.5          0.2
# 11           11           4.8          3.4           1.6          0.2
# ...

# %% [markdown]
# Create dummy variables of the species name and concatenate onto the iris dataframe. (This is for practice, we don't always have to encode the target, but if we used species as a feature, we would need to encode it).

# %%
dummies = pd.get_dummies(iris_df[['species']],drop_first = [True])
iris_df = pd.concat([iris_df,dummies], axis = 1)

# %% [markdown]
# Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %%
def clean_iris(df):
    df.drop(['measurement_id','species_id'], axis = 1, inplace = True)
    df.rename(columns = {'species_name':'species'}, inplace = True)
    dummies = pd.get_dummies(df[['species']],drop_first = [True, True])
    df = pd.concat([df,dummies], axis = 1)
    return df

iris_dirty = acquire.get_iris_data()

clean_iris(iris_dirty)
# Out:
#      Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
# 0             0           5.1          3.5           1.4          0.2
# 1             1           4.9          3.0           1.4          0.2
# 2             2           4.7          3.2           1.3          0.2
# 3             3           4.6          3.1           1.5          0.2
# 4             4           5.0          3.6           1.4          0.2
# 5             5           5.4          3.9           1.7          0.4
# 6             6           4.6          3.4           1.4          0.3
# 7             7           5.0          3.4           1.5          0.2
# 8             8           4.4          2.9           1.4          0.2
# 9             9           4.9          3.1           1.5          0.1
# 10           10           5.4          3.7           1.5          0.2
# 11           11           4.8          3.4           1.6          0.2
# ...

# %% [markdown]
# Using the Titanic dataset
#
# Use the function defined in acquire.py to load the Titanic data.

# %%
titanic_df = acquire.get_titanic_data()
titanic_df
# Out:
#      Unnamed: 0  passenger_id  survived  pclass     sex   age  sibsp  parch  \
# 0             0             0         0       3    male  22.0      1      0
# 1             1             1         1       1  female  38.0      1      0
# 2             2             2         1       3  female  26.0      0      0
# 3             3             3         1       1  female  35.0      1      0
# 4             4             4         0       3    male  35.0      0      0
# ..          ...           ...       ...     ...     ...   ...    ...    ...
# 886         886           886         0       2    male  27.0      0      0
# 887         887           887         1       1  female  19.0      0      0
# 888         888           888         0       3  female   NaN      1      2
# 889         889           889         1       1    male  26.0      0      0
# 890         890           890         0       3    male  32.0      0      0
#
#         fare embarked   class deck  embark_town  alone
# ...

# %% [markdown]
# Drop any unnecessary, unhelpful, or duplicated columns.

# %%
titanic_df.drop([titanic_df.columns[0], 'passenger_id', 'deck', 'embarked','class'], axis = 1, inplace = True)

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  embark_town  alone
# 0           0       3    male  22.0      1      0   7.2500  Southampton      0
# 1           1       1  female  38.0      1      0  71.2833    Cherbourg      0
# 2           1       3  female  26.0      0      0   7.9250  Southampton      1
# 3           1       1  female  35.0      1      0  53.1000  Southampton      0
# 4           0       3    male  35.0      0      0   8.0500  Southampton      1
# ..        ...     ...     ...   ...    ...    ...      ...          ...    ...
# 886         0       2    male  27.0      0      0  13.0000  Southampton      1
# 887         1       1  female  19.0      0      0  30.0000  Southampton      1
# 888         0       3  female   NaN      1      2  23.4500  Southampton      0
# 889         1       1    male  26.0      0      0  30.0000    Cherbourg      1
# 890         0       3    male  32.0      0      0   7.7500   Queenstown      1
#
# [891 rows x 9 columns]

# %% [markdown]
# Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
titanic_df['embark_town'].fillna('Southampton',inplace = True)
dummies = pd.get_dummies(titanic_df[['sex','embark_town']],drop_first = [(True, True])
titanic_df = pd.concat([titanic_df,dummies], axis = 1)

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  embark_town  \
# 0           0       3    male  22.0      1      0   7.2500  Southampton
# 1           1       1  female  38.0      1      0  71.2833    Cherbourg
# 2           1       3  female  26.0      0      0   7.9250  Southampton
# 3           1       1  female  35.0      1      0  53.1000  Southampton
# 4           0       3    male  35.0      0      0   8.0500  Southampton
# ..        ...     ...     ...   ...    ...    ...      ...          ...
# 886         0       2    male  27.0      0      0  13.0000  Southampton
# 887         1       1  female  19.0      0      0  30.0000  Southampton
# 888         0       3  female   NaN      1      2  23.4500  Southampton
# 889         1       1    male  26.0      0      0  30.0000    Cherbourg
# 890         0       3    male  32.0      0      0   7.7500   Queenstown
#
#      alone  sex_male  embark_town_Queenstown  embark_town_Southampton
# ...

# %% [markdown]
# Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

# %%
def clean_titanic(df):
    df.drop([titanic_df.columns[0], 'passenger_id', 'deck', 'embarked','class'], axis = 1, inplace = True)
    df['embark_town'].fillna('Southampton',inplace = True)
    dummies = pd.get_dummies(df[['sex','embark_town']],drop_first = [True, True])
    df = pd.concat([df,dummies], axis = 1)
    return df

dirty_titanic = acquire.get_titanic_data()
clean_titanic(dirty_titanic)
# Out:
#      Unnamed: 0  pclass     sex   age  sibsp  parch     fare  embark_town  \
# 0             0       3    male  22.0      1      0   7.2500  Southampton
# 1             1       1  female  38.0      1      0  71.2833    Cherbourg
# 2             2       3  female  26.0      0      0   7.9250  Southampton
# 3             3       1  female  35.0      1      0  53.1000  Southampton
# 4             4       3    male  35.0      0      0   8.0500  Southampton
# ..          ...     ...     ...   ...    ...    ...      ...          ...
# 886         886       2    male  27.0      0      0  13.0000  Southampton
# 887         887       1  female  19.0      0      0  30.0000  Southampton
# 888         888       3  female   NaN      1      2  23.4500  Southampton
# 889         889       1    male  26.0      0      0  30.0000    Cherbourg
# 890         890       3    male  32.0      0      0   7.7500   Queenstown
#
#      alone  sex_male  embark_town_Queenstown  embark_town_Southampton
# ...

# %% [markdown]
# Using the Telco dataset
#
# Use the function defined in acquire.py to load the Telco data.

# %%
telco_df = acquire.get_telco_data()

# %%
telco_df.nunique()
# Out:
# Unnamed: 0                  7043
# payment_type_id                4
# internet_service_type_id       3
# contract_type_id               3
# customer_id                 7043
# gender                         2
# senior_citizen                 2
# partner                        2
# dependents                     2
# tenure                        73
# phone_service                  2
# multiple_lines                 3
# online_security                3
# online_backup                  3
# device_protection              3
# tech_support                   3
# streaming_tv                   3
# streaming_movies               3
# paperless_billing              2
# monthly_charges             1585
# total_charges               6531
# churn                          2
# contract_type                  3
# internet_service_type          3
# payment_type                   4
# dtype: int64

# %% [markdown]
# Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.

# %%
telco_df.drop([telco_df.columns[0], 'payment_type_id','internet_service_type_id','contract_type_id'], axis = 1, inplace = True)

# %%
telco_df.head(2)
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9
# 1  0003-MKNFE    Male               0      No         No       9
#
#   phone_service multiple_lines online_security online_backup  ...  \
# 0           Yes             No              No           Yes  ...
# 1           Yes            Yes              No            No  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# 0          Yes          Yes               No               Yes
# 1           No           No              Yes                No
#
#   monthly_charges  total_charges churn   contract_type internet_service_type  \
# 0            65.6          593.3    No        One year                   DSL
# 1            59.9          542.4    No  Month-to-month                   DSL
#
#    payment_type
# 0  Mailed check
# 1  Mailed check
#
# [2 rows x 21 columns]

# %% [markdown]
# Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.

# %%
dummies = pd.get_dummies(telco_df[['partner','dependents', 'phone_service','multiple_lines','online_security','online_backup', 'tech_support','streaming_tv','streaming_movies','paperless_billing','churn', 'contract_type']],drop_first = [True, True])
telco_df = pd.concat([telco_df,dummies], axis = 1)
telco_df.head(2)
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9
# 1  0003-MKNFE    Male               0      No         No       9
#
#   phone_service multiple_lines online_security online_backup  ...  \
# 0           Yes             No              No           Yes  ...
# 1           Yes            Yes              No            No  ...
#
#   tech_support_No internet service tech_support_Yes  \
# 0                                0                1
# 1                                0                0
#
#   streaming_tv_No internet service streaming_tv_Yes  \
# 0                                0                1
# 1                                0                0
#
#   streaming_movies_No internet service  streaming_movies_Yes  \
# 0                                    0                     0
# 1                                    0                     1
#
# ...

# %% [markdown]
# Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.

# %%
def telco_clean(df):
    df.drop([df.columns[0], 'payment_type_id','internet_service_type_id','contract_type_id'], axis = 1, inplace = True)
    dummies = pd.get_dummies(df[['partner','dependents', 'phone_service','multiple_lines','online_security','online_backup', 'tech_support','streaming_tv','streaming_movies','paperless_billing','churn', 'contract_type']],drop_first = [True])
    df = pd.concat([df,dummies], axis = 1)
    return df

# %%
telco_dirty = acquire.get_telco_data()
telco_clean(telco_dirty)
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 0     0002-ORFBO  Female               0     Yes        Yes       9
# 1     0003-MKNFE    Male               0      No         No       9
# 2     0004-TLHLJ    Male               0      No         No       4
# 3     0011-IGKFF    Male               1     Yes         No      13
# 4     0013-EXCHZ  Female               1     Yes         No       3
# ...          ...     ...             ...     ...        ...     ...
# 7038  9987-LUTYD  Female               0      No         No      13
# 7039  9992-RRAMN    Male               0     Yes         No      22
# 7040  9992-UJOEL    Male               0      No         No       2
# 7041  9993-LHIEB    Male               0     Yes        Yes      67
# 7042  9995-HOTOH    Male               0     Yes        Yes      63
#
#      phone_service    multiple_lines online_security online_backup  ...  \
# 0              Yes                No              No           Yes  ...
# ...

# %% [markdown]
# Split your data

# %%
seed = 42
train, val_test = train_test_split(telco_df, train_size = 0.7, random_state = seed)
validate, test = train_test_split(val_test, train_size = 0.5, random_state = seed)

# %% [markdown]
# Write a function to split your data into train, test and validate datasets. Add this function to prepare.py.

# %%
def train_val_test(df):
    seed = 42
    train, val_test = train_test_split(df, train_size = 0.7, random_state = seed)
    validate, test = train_test_split(val_test, train_size = 0.5, random_state = seed)
    return train, validate, test

# %% [markdown]
# Run the function in your notebook on the Iris dataset, returning 3 datasets, train_iris, validate_iris and test_iris.

# %%
prepare.train_val_test(iris_df)
# Out:
# (     Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width  \
#  81           81           5.5          2.4           3.7          1.0
#  133         133           6.3          2.8           5.1          1.5
#  137         137           6.4          3.1           5.5          1.8
#  75           75           6.6          3.0           4.4          1.4
#  109         109           7.2          3.6           6.1          2.5
#  96           96           5.7          2.9           4.2          1.3
#  105         105           7.6          3.0           6.6          2.1
#  66           66           5.6          3.0           4.5          1.5
#  0             0           5.1          3.5           1.4          0.2
#  122         122           7.7          2.8           6.7          2.0
#  67           67           5.8          2.7           4.1          1.0
#  28           28           5.2          3.4           1.4          0.2
# ...

# %% [markdown]
# Run the function on the Titanic dataset, returning 3 datasets, train_titanic, validate_titanic and test_titanic.

# %%
prepare.train_val_test(titanic_df)
# Out:
# (     survived  pclass     sex   age  sibsp  parch      fare  embark_town  \
#  445         1       1    male   4.0      0      2   81.8583  Southampton
#  650         0       3    male   NaN      0      0    7.8958  Southampton
#  172         1       3  female   1.0      1      1   11.1333  Southampton
#  450         0       2    male  36.0      1      2   27.7500  Southampton
#  314         0       2    male  43.0      1      1   26.2500  Southampton
#  ..        ...     ...     ...   ...    ...    ...       ...          ...
#  106         1       3  female  21.0      0      0    7.6500  Southampton
#  270         0       1    male   NaN      0      0   31.0000  Southampton
#  860         0       3    male  41.0      2      0   14.1083  Southampton
#  435         1       1  female  14.0      1      2  120.0000  Southampton
#  102         0       1    male  21.0      0      1   77.2875  Southampton
#
#       alone  sex_male  embark_town_Queenstown  embark_town_Southampton
# ...

# %% [markdown]
# Run the function on the Telco dataset, returning 3 datasets, train_telco, validate_telco and test_telco.

# %%
prepare.train_val_test(telco_df)
# Out:
# (     customer_id  gender  senior_citizen partner dependents  tenure  \
#  1695  2472-OVKUP    Male               0     Yes         No       6
#  1095  1596-BBVTG    Male               0      No         No      35
#  3889  5469-NUJUR    Male               0      No         No      19
#  3667  5175-WLYXL    Male               0      No         No      22
#  2902  4134-BSXLX    Male               0     Yes         No      28
#  ...          ...     ...             ...     ...        ...     ...
#  3772  5310-NOOVA    Male               0      No         No      46
#  5191  7302-ZHMHP  Female               0      No         No       1
#  5226  7356-AYNJP  Female               0      No         No       4
#  5390  7601-WFVZV    Male               0      No         No       1
#  860   1248-DYXUB    Male               0     Yes        Yes      52
#
#       phone_service multiple_lines      online_security        online_backup  \
# ...

# %%
categorical=[]
numerical = []

# %%
for col in telco.columns:
    if telco[col]

# %%
def train_val_test(df, target = ''):
    seed = 42
    train, val_test = train_test_split(df, train_size = 0.7, random_state = seed, stratify = target)
    validate, test = train_test_split(val_test, train_size = 0.5, random_state = seed, stratify = target
    return train, validate, test
                                      
#example from review
